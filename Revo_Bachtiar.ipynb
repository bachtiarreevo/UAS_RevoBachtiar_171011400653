# %% [markdown]
# **Gray Image**

# %%
import numpy as np
import matplotlib.pyplot as plt
random_image = np.random.random([500,500])
plt.imshow(random_image, cmap = 'gray')
plt.colorbar();

# %% [markdown]
# **Skala gambar dan bentuk**

# %%
#Checking out a color image 
from skimage import data 
kucing = data.chelsea ()
print (f'Shape: {kucing.shape} ') 
print ("Nilai min / maks", kucing.min (), kucing.max ()) 
plt.imshow (kucing)
# Out:
# Shape: (300, 451, 3)
# Nilai min / maks 0 231

# %% [markdown]
# **Menggambar kotak merah**

# %%
#Drawing a red square on the image
cat[10:110, 10:110, :] = [150, 0, 0] #{red, green, blue }
plt.imshow(cat)
